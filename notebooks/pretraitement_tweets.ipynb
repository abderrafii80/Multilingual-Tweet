# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Charger le fichier JSON
file_path = 'cleaned_tweets_fr.json'  # Remplacez par le chemin vers votre fichier JSON
with open(os.path.join("../data/cleaned",file_path), 'r', encoding='utf-8') as file:
    data = json.load(file)

# Convertir en DataFrame
df = pd.DataFrame(data)
df
# Out:
#               tweet_id                                               text  \
# 0  1858189684943265825                      covid vrai ca jetonnais honte
# 1  1858189572150067631  raison medias proposent jamais poser bonnes qu...
# 2  1858189551329493279  lanceur dalerte obtenu go linstitut robert koc...
# 3  1858189437819347092  covid effets secondaires vaccns dernieres reve...
# 4  1858189382278156770  technique imparable caste pouvoir ans faire ad...
# 5  1858189369854595534  fraudulent science linno tavait ca reviendrait...
# 6  1858189363223683086                                grossit covid manne
# 7  1858189359700201912  didier netes credible affirme chloroquine soig...
# 8  1858189250023354659  jai simplement critique dessin faisais penser ...
# 9  1858189193085686010  sante effets secondaires nexistent vaccination...
#
#       created_at            author_id  \
# 0  1731861919000  1801562435813281793
# 1  1731861892000  1283275292019228672
# 2  1731861887000  1840001168438689792
# 3  1731861860000           3394102223
# 4  1731861846000            206513780
# 5  1731861843000  1428599123348004864
# 6  1731861842000  1400182391487045636
# 7  1731861841000            548728549
# 8  1731861815000  1678100076227379201
# 9  1731861801000  1698633392118439936
#
#                                  context_annotations  language
# 0  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  français
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 3  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 4  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 5                                               None  français
# 6  [{'domain': {'id': '45', 'name': 'Brand Vertic...  français
# 7  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 8  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 9  [{'domain': {'id': '123', 'name': 'Ongoing New...  français

# %%
# Charger le fichier JSON
file_path = 'cleaned_tweets_en.json'  # Remplacez par le chemin vers votre fichier JSON
with open(os.path.join("../data/cleaned",file_path), 'r', encoding='utf-8') as file:
    data = json.load(file)

# Convertir en DataFrame
df_en = pd.DataFrame(data)
df_en
# Out:
#               tweet_id                                               text  \
# 0  1858193473310232643            bet refused wear mask covid brave flags
# 1  1858193469514117584  difference covid vaccination differences healt...
# 2  1858193458923794624  weeks providential dad returned hospital covid...
# 3  1858193422462357519  believed california democrat middleoftheroad m...
# 4  1858193412777709863  study patients cancer treated cancer center co...
# 5  1858193411875954981                cook stipe fight covid stipe chance
# 6  1858193410332459383  lol job rachel keeping americans safe healthy ...
# 7  1858193406377291828  covid lockdowns commie ny cuomo live everyday ...
# 8  1858193405534142662                                     feed covid lab
# 9  1858193397346885672  imagine guilt family childrens doctorssurgeons...
#
#       created_at            author_id  \
# 0  1731862822000             22534554
# 1  1731862821000           2590663369
# 2  1731862818000  1380668071921221636
# 3  1731862810000             42666106
# 4  1731862807000   850455051965431808
# 5  1731862807000  1825251921294241795
# 6  1731862807000  1738328371531001857
# 7  1731862806000  1550947085226221570
# 8  1731862806000  1591770680743415808
# 9  1731862804000  1751925051476320257
#
#                                  context_annotations language
# 0  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 1  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 3  [{'domain': {'id': '10', 'name': 'Person', 'de...  anglais
# 4  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 5  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 6  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 7  [{'domain': {'id': '46', 'name': 'Business Tax...  anglais
# 8  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 9  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais

# %%
# Charger le fichier JSON
file_path = 'cleaned_tweets_ar.json'  # Remplacez par le chemin vers votre fichier JSON
with open(os.path.join("../data/cleaned",file_path), 'r', encoding='utf-8') as file:
    data = json.load(file)

# Convertir en DataFrame
df_ar = pd.DataFrame(data)
df_ar
# Out:
#               tweet_id                                               text  \
# 0  1858135995268436245                                            فدات شم
# 1  1858097362977046848  شاهدقصف عنيف يدمر بناية سكنية اساسها جنوب لبنا...
# 2  1857992683945406879                                      covid حب بلوط
# 3  1857768485411066214                  استشاري طبيبك تكون covid قذر الله
# 4  1857762421177286983  who exitthewho رسالةاليوم الوعيالجمعي اجندة لق...
# 5  1857726338687180811  دراسة طبية كليفلاند كلينيك تحذر حالات التهاب ع...
# 6  1857726149675172271  الايدز الناجم اللقاح السجلات العسكرية تزيد بنس...
# 7  1857725946427527670  تشير بيانات حكومة كندا covid معظم المطعمين بال...
# 8  1857725820095111678  نتايج فحص الدكتوره zandre botha تخصص ميكروسكوب...
# 9  1857701949602189786  اعلن rfk سيرفع دعوى قضايية شركات الادوية الكبر...
#
#       created_at            author_id  \
# 0  1731849118000  1331904918085627904
# 1  1731839907000  1750241238177976320
# 2  1731814950000  1186339095632584704
# 3  1731761497000  1780201089968570368
# 4  1731760051000           3283099778
# 5  1731751448000  1680924615252627456
# 6  1731751403000  1680924615252627456
# 7  1731751355000  1680924615252627456
# 8  1731751325000  1680924615252627456
# 9  1731745633000            563178346
#
#                                  context_annotations language
# 0                                               None    arabe
# 1  [{'domain': {'id': '69', 'name': 'News Vertica...    arabe
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 3  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 4  [{'domain': {'id': '65', 'name': 'Interests an...    arabe
# 5                                               None    arabe
# 6  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 7  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 8                                               None    arabe
# 9  [{'domain': {'id': '46', 'name': 'Business Tax...    arabe

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               tweet_id                                               text  \
# 0  1858189684943265825                      covid vrai ca jetonnais honte
# 1  1858189572150067631  raison medias proposent jamais poser bonnes qu...
# 2  1858189551329493279  lanceur dalerte obtenu go linstitut robert koc...
# 3  1858189437819347092  covid effets secondaires vaccns dernieres reve...
# 4  1858189382278156770  technique imparable caste pouvoir ans faire ad...
# 5  1858189369854595534  fraudulent science linno tavait ca reviendrait...
# 6  1858189363223683086                                grossit covid manne
# 7  1858189359700201912  didier netes credible affirme chloroquine soig...
# 8  1858189250023354659  jai simplement critique dessin faisais penser ...
# 9  1858189193085686010  sante effets secondaires nexistent vaccination...
#
#       created_at            author_id  \
# 0  1731861919000  1801562435813281793
# 1  1731861892000  1283275292019228672
# 2  1731861887000  1840001168438689792
# 3  1731861860000           3394102223
# 4  1731861846000            206513780
# 5  1731861843000  1428599123348004864
# 6  1731861842000  1400182391487045636
# 7  1731861841000            548728549
# 8  1731861815000  1678100076227379201
# 9  1731861801000  1698633392118439936
#
#                                  context_annotations  language
# 0  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...  français
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 3  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 4  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 5                                               None  français
# 6  [{'domain': {'id': '45', 'name': 'Brand Vertic...  français
# 7  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 8  [{'domain': {'id': '123', 'name': 'Ongoing New...  français
# 9  [{'domain': {'id': '123', 'name': 'Ongoing New...  français  >

# %%
df_en.describe
# Out:
# <bound method NDFrame.describe of               tweet_id                                               text  \
# 0  1858193473310232643            bet refused wear mask covid brave flags
# 1  1858193469514117584  difference covid vaccination differences healt...
# 2  1858193458923794624  weeks providential dad returned hospital covid...
# 3  1858193422462357519  believed california democrat middleoftheroad m...
# 4  1858193412777709863  study patients cancer treated cancer center co...
# 5  1858193411875954981                cook stipe fight covid stipe chance
# 6  1858193410332459383  lol job rachel keeping americans safe healthy ...
# 7  1858193406377291828  covid lockdowns commie ny cuomo live everyday ...
# 8  1858193405534142662                                     feed covid lab
# 9  1858193397346885672  imagine guilt family childrens doctorssurgeons...
#
#       created_at            author_id  \
# 0  1731862822000             22534554
# 1  1731862821000           2590663369
# 2  1731862818000  1380668071921221636
# 3  1731862810000             42666106
# 4  1731862807000   850455051965431808
# 5  1731862807000  1825251921294241795
# 6  1731862807000  1738328371531001857
# 7  1731862806000  1550947085226221570
# 8  1731862806000  1591770680743415808
# 9  1731862804000  1751925051476320257
#
#                                  context_annotations language
# 0  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 1  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 3  [{'domain': {'id': '10', 'name': 'Person', 'de...  anglais
# 4  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 5  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 6  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 7  [{'domain': {'id': '46', 'name': 'Business Tax...  anglais
# 8  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais
# 9  [{'domain': {'id': '123', 'name': 'Ongoing New...  anglais  >

# %%
df_ar.describe
# Out:
# <bound method NDFrame.describe of               tweet_id                                               text  \
# 0  1858135995268436245                                            فدات شم
# 1  1858097362977046848  شاهدقصف عنيف يدمر بناية سكنية اساسها جنوب لبنا...
# 2  1857992683945406879                                      covid حب بلوط
# 3  1857768485411066214                  استشاري طبيبك تكون covid قذر الله
# 4  1857762421177286983  who exitthewho رسالةاليوم الوعيالجمعي اجندة لق...
# 5  1857726338687180811  دراسة طبية كليفلاند كلينيك تحذر حالات التهاب ع...
# 6  1857726149675172271  الايدز الناجم اللقاح السجلات العسكرية تزيد بنس...
# 7  1857725946427527670  تشير بيانات حكومة كندا covid معظم المطعمين بال...
# 8  1857725820095111678  نتايج فحص الدكتوره zandre botha تخصص ميكروسكوب...
# 9  1857701949602189786  اعلن rfk سيرفع دعوى قضايية شركات الادوية الكبر...
#
#       created_at            author_id  \
# 0  1731849118000  1331904918085627904
# 1  1731839907000  1750241238177976320
# 2  1731814950000  1186339095632584704
# 3  1731761497000  1780201089968570368
# 4  1731760051000           3283099778
# 5  1731751448000  1680924615252627456
# 6  1731751403000  1680924615252627456
# 7  1731751355000  1680924615252627456
# 8  1731751325000  1680924615252627456
# 9  1731745633000            563178346
#
#                                  context_annotations language
# 0                                               None    arabe
# 1  [{'domain': {'id': '69', 'name': 'News Vertica...    arabe
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 3  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 4  [{'domain': {'id': '65', 'name': 'Interests an...    arabe
# 5                                               None    arabe
# 6  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 7  [{'domain': {'id': '123', 'name': 'Ongoing New...    arabe
# 8                                               None    arabe
# 9  [{'domain': {'id': '46', 'name': 'Business Tax...    arabe  >

# %% [markdown]
# ## Histogramme de Longeur de titre (Frensh)

# %%
# Calcul de la longueur des titres
df['title_length'] = df['text'].apply(lambda x: len(x.split()))

# Histogramme de la longueur des titres
plt.figure(figsize=(10, 6))
sns.histplot(df['title_length'], kde=True, bins=30)
plt.title("Distribution des longueurs des titres")
plt.xlabel("Longueur du titre (nombre de mots)")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# ## Histogramme de Longeur de titre (Anglais)

# %%
# Calcul de la longueur des titres
df_en['title_length'] = df_en['text'].apply(lambda x: len(x.split()))

# Histogramme de la longueur des titres
plt.figure(figsize=(10, 6))
sns.histplot(df_en['title_length'], kde=True, bins=30)
plt.title("Distribution des longueurs des titres")
plt.xlabel("Longueur du titre (nombre de mots)")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# ## Histogramme de Longeur de titre (Araic)

# %%
# Calcul de la longueur des titres
df_ar['title_length'] = df_ar['text'].apply(lambda x: len(x.split()))

# Histogramme de la longueur des titres
plt.figure(figsize=(10, 6))
sns.histplot(df_ar['title_length'], kde=True, bins=30)
plt.title("Distribution des longueurs des titres")
plt.xlabel("Longueur du titre (nombre de mots)")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# ## Analyse des mots (Frensh)

# %%
# Analyser la fréquence des termes dans les titres
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words='english', max_features=20)  # Top 20 mots fréquents
X = vectorizer.fit_transform(df['text'])

# Afficher les mots les plus fréquents
frequent_terms = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
print(frequent_terms.sum().sort_values(ascending=False).head(20))
# Out:
# covid                 9
# sante                 3
# effets                2
# ca                    2
# secondaires           2
# vaccination           2
# allemand              1
# advenir               1
# attendent             1
# antivaxx              1
# bientot               1
# autorite              1
# clairement            1
# caste                 1
# canard                1
# bonnes                1
# bardella              1
# combat                1
# climatoscepticisme    1
# coincidence           1
# dtype: int64

# %% [markdown]
# ## Analyse des mots (Anglais)

# %%
# Analyser la fréquence des termes dans les titres
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words='english', max_features=20)  # Top 20 mots fréquents
X = vectorizer.fit_transform(df_en['text'])

# Afficher les mots les plus fréquents
frequent_terms = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
print(frequent_terms.sum().sort_values(ascending=False).head(20))
# Out:
# covid           10
# cancer           3
# care             2
# stipe            2
# bet              1
# batch            1
# americans        1
# activist         1
# bunch            1
# bucket           1
# biden            1
# brave            1
# caught           1
# california       1
# center           1
# chance           1
# commie           1
# childrens        1
# cook             1
# consistently     1
# dtype: int64

# %% [markdown]
# ## Analyse des mots (Arabic)

# %%
# Analyser la fréquence des termes dans les titres
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words='english', max_features=20)  # Top 20 mots fréquents
X = vectorizer.fit_transform(df_ar['text'])

# Afficher les mots les plus fréquents
frequent_terms = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
print(frequent_terms.sum().sort_values(ascending=False).head(20))
# Out:
# covid         7
# لقاح          3
# المناعة       3
# mrna          2
# الايدز        2
# جنوب          2
# نقص           2
# بالكامل       2
# mali          1
# kiev          1
# exitthewho    1
# zelinsky      1
# افريقيا       1
# اعلن          1
# اخذ           1
# اجهزة         1
# اجندة         1
# ابدا          1
# الادوية       1
# الاسراييلي    1
# dtype: int64

# %% [markdown]
# ## Boxplot des longeurs des titres (Frensh)

# %%
# Boxplot des longueurs de texte
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['title_length'])
plt.title("Boxplot de la longueur des titres")
plt.show()

# Pairplot pour examiner les relations entre les variables numériques
sns.pairplot(df[['title_length']])  # Ajouter d'autres variables numériques ici si nécessaire
plt.show()

# %% [markdown]
# ## Boxplot des longeurs des titres (Anglais)

# %%
# Boxplot des longueurs de texte
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_en['title_length'])
plt.title("Boxplot de la longueur des titres")
plt.show()

# Pairplot pour examiner les relations entre les variables numériques
sns.pairplot(df_en[['title_length']])  # Ajouter d'autres variables numériques ici si nécessaire
plt.show()

# %% [markdown]
# ## Boxplot des longeurs des titres (Arabic)

# %%
# Boxplot des longueurs de texte
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_ar['title_length'])
plt.title("Boxplot de la longueur des titres")
plt.show()

# Pairplot pour examiner les relations entre les variables numériques
sns.pairplot(df_ar[['title_length']])  # Ajouter d'autres variables numériques ici si nécessaire
plt.show()

# %% [markdown]
# ## Nuage des donnees (FRENSH) cleaned_google_news_fr

# %%
from wordcloud import WordCloud

# Générer le nuage de mots à partir des titres
wordcloud = WordCloud(background_color='white', width=800, height=400,max_words=90).generate(' '.join(df['text']))

# Afficher le nuage de mots
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Nuage des donnees (ANGLAIS) cleaned_google_news_en

# %%
from wordcloud import WordCloud

# Générer le nuage de mots à partir des titres
wordcloud = WordCloud(background_color='white', width=800, height=400).generate(' '.join(df_en['text']))

# Afficher le nuage de mots
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Nuage des donnees (ARABIC) cleaned_google_news_ar

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

# Préparer les titres en arabe
titles_ar = ' '.join(df_ar['text'])

# Reshaper le texte arabe pour une ligature correcte
reshaped_text = arabic_reshaper.reshape(titles_ar)

# Inverser le texte pour l'affichage correct de droite à gauche
bidi_text = get_display(reshaped_text)

# Générer le nuage de mots
font_path = r"C:\Users\hp\AppData\Local\Microsoft\Windows\Fonts\maghribi-font 2.ttf"
wordcloud = WordCloud( background_color='white',width=800,height=400,font_path=font_path).generate(bidi_text)

# Afficher le nuage de mots
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
